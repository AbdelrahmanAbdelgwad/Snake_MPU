# %%
import pynput
import serial

# %%
from pynput.keyboard import Key, Controller

# %%
keyboard = Controller()
Arduino_Serial = serial.Serial('COM3', 115200)
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1480/1265011271.py in <module>
#       1 keyboard = Controller()
# ----> 2 Arduino_Serial = serial.Serial('COM3', 115200)
#
# C:\ProgramData\Anaconda3\lib\site-packages\serial\serialwin32.py in __init__(self, *args, **kwargs)
#      31         self._overlapped_read = None
#      32         self._overlapped_write = None
# ---> 33         super(Serial, self).__init__(*args, **kwargs)
#      34
#      35     def open(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\serial\serialutil.py in __init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     242
#     243         if port is not None:
# --> 244             self.open()
#     245
#     246     #  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#
# C:\ProgramData\Anaconda3\lib\site-packages\serial\serialwin32.py in open(self)
#      62         if self._port_handle == win32.INVALID_HANDLE_VALUE:
#      63             self._port_handle = None    # 'cause __del__ is called anyway
# ---> 64             raise SerialException("could not open port {!r}: {!r}".format(self.portstr, ctypes.WinError()))
#      65
#      66         try:
#
# SerialException: could not open port 'COM3': FileNotFoundError(2, 'The system cannot find the file specified.', None, 2)

# %%
while 1:
    incoming_data = str(Arduino_Serial.readline())
    print(incoming_data)

    if 'R' in incoming_data:
        keyboard.press(Key.right)
        keyboard.release(Key.right)
    elif "U" in incoming_data:
        keyboard.press(Key.up)
        keyboard.release(Key.up)
    elif 'L' in incoming_data:
        keyboard.press(Key.left)
        keyboard.release(Key.left)
    elif 'D' in incoming_data:
        keyboard.press(Key.down)
        keyboard.release(Key.down)
# Out:
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# ...
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'R\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'R\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'L\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'L\r\n'
# b'R\r\n'
# b'U\r\n'
# b'U\r\n'
# b'U\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'D\r\n'
# b'L\r\n'
# b'U\r\n'
# b'L\r\n'
# b'R\r\n'
# b'R\r\n'
# b'D\r\n'
# b'U\r\n'
# b''
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6580/2720440584.py in <module>
#       1 while 1:
# ----> 2     incoming_data = str(Arduino_Serial.readline())
#       3     print(incoming_data)
#       4
#       5     if 'R' in incoming_data:
#
# C:\ProgramData\Anaconda3\lib\site-packages\serial\serialwin32.py in read(self, size)
#     273             comstat = win32.COMSTAT()
#     274             if not win32.ClearCommError(self._port_handle, ctypes.byref(flags), ctypes.byref(comstat)):
# --> 275                 raise SerialException("ClearCommError failed ({!r})".format(ctypes.WinError()))
#     276             n = min(comstat.cbInQue, size) if self.timeout == 0 else size
#     277             if n > 0:
#
# SerialException: ClearCommError failed (PermissionError(13, 'The device does not recognize the command.', None, 22))
